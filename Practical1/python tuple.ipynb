# %%
x = ("Harsh", "Dhruv", "Nihar")
print(x)
# Out:
# ('Harsh', 'Dhruv', 'Nihar')

# %%
print(len(x))
# Out:
# 3

# %%
print(type(x))
# Out:
# <class 'tuple'>

# %%
y = tuple(("Jay", "Utkarsh", "devansu"))
print(y)
# Out:
# ('Jay', 'Utkarsh', 'devansu')

# %%
mytuple = ("harsh", "Jay", "Utkarsh", "Nihar", "Dhruv")
print(mytuple[1])
print(mytuple[0])
print(mytuple[-1])
# Out:
# Jay
# harsh
# Dhruv

# %%
print(mytuple[1:4])
# Out:
# ('Jay', 'Utkarsh', 'Nihar')

# %%
print(mytuple[2:])
print(mytuple[:3])
# Out:
# ('Utkarsh', 'Nihar', 'Dhruv')
# ('harsh', 'Jay', 'Utkarsh')

# %%
print(x)
# Out:
# ('Harsh', 'Dhruv', 'Nihar')

# %%
mytuple = ("harsh", "Jay", "Utkarsh", "Nihar", "Dhruv")
if "harsh" in mytuple:
    print("yes")
# Out:
# yes

# %%
x = ("Utkarsh", "Nihar", "Dhruv")
y = list(x)
y[1] = "Harsh"
x = tuple(y)

print(x)
# Out:
# ('Utkarsh', 'Harsh', 'Dhruv')

# %%
x = ('Utkarsh', 'Harsh', 'Dhruv')
y = list(x)
y.append("Nihar")
x = tuple(y)
print(x)
# Out:
# ('Utkarsh', 'Harsh', 'Dhruv', 'Nihar')

# %%
x = ('Utkarsh', 'Harsh', 'Dhruv')
y = list(x)
y.remove("Utkarsh")
x = tuple(y)
print(x)
# Out:
# ('Harsh', 'Dhruv')

# %%
Names = ("harsh", "Jay", "Utkarsh", "Nihar", "Dhruv")

(more, patel, *modi) = Names

print(more)
print(patel)
print(modi)
# Out:
# harsh
# Jay
# ['Utkarsh', 'Nihar', 'Dhruv']

# %%
thistuple = ("dhruv", "Jay", "Nihar")
for x in thistuple:
  print(x)
# Out:
# dhruv
# Jay
# Nihar

# %%
thistuple = ("dhruv", "Jay", "Nihar")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# dhruv
# Jay
# Nihar

# %%
thistuple = ("dhruv", "Jay", "Nihar")
i = 0

while i < len(thistuple):
  print(thistuple[i])
  i = i+1
# Out:
# dhruv
# Jay
# Nihar

# %%
t1 = ("H", "A", "R", "S", "H")
t2 = (1, 2, 3, 4)

t3 = t1 + t2
print(t3)
# Out:
# ('H', 'A', 'R', 'S', 'H', 1, 2, 3, 4)

# %%
t1 = ("H", "A", "R", "S", "H")

t3 = t1 * 2
print(t3)
# Out:
# ('H', 'A', 'R', 'S', 'H', 'H', 'A', 'R', 'S', 'H')
